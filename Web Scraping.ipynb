# %%
from bs4 import BeautifulSoup
from urllib.request import urlopen as uReq
url = "http://forem.co.in/members.html"
# Make a GET request to fetch the raw HTML content
html_content = uReq(url)

# Parse the html content
soup = BeautifulSoup(html_content, "lxml")
#print(soup.prettify()) # print the parsed data of html

from collections import defaultdict
data = {}
table1 = soup.find("table", attrs={"class": "table"})
table_data = table1.findAll("tr")  # contains 71 rows
table_data[1]
# Get all the headings of Lists
headings = []
for th in table_data[0].findAll("th"):
    # remove any newlines and extra spaces from left and right
    headings.append(th.text.replace('\n', ' '))

t_headers = []

for i in range(len(table_data)):
    for th in table_data[i].findAll("td"):
        # remove any newlines and extra spaces from left and right
        t_headers.append(th.text.replace('\n', ' ').strip())
        
res=[]
for i in range(0,len(t_headers),len(headings)):
    res.append(t_headers[i:i+5])
temp = defaultdict(list)
for i in range(len(res)):
    class_list = headings
    id_list = res[i]
    for key, value in zip(class_list, id_list):
        temp[key].append(value)
headings
# Out:
# ['S.No.', 'Name of Member', 'Event Company', 'Contact No.', 'Email ID']

# %%
# print the contents using zip format. 
res=[]
for each_row in zip(*([i] + (j) for i, j in temp.items())): 
      res.append((*each_row,))
    
# Using pandas to clean data    
import pandas as pd
df=pd.DataFrame(res)
new_header = df.iloc[0] #grab the first row for the header
df = df[1:] #take the data less the header row
df.columns = new_header #set the header row as the df header

data=df
# dropping null value columns to avoid errors 
data.dropna(inplace = True) 
#Renaming old column names
data["Organization Name"]=data["Event Company"]
data["Contact Person Name"]=data["Name of Member"]
# Dropping old columns 
data.drop(columns =["Event Company"], inplace = True) 
data.drop(columns =["Name of Member"], inplace = True) 
# new data frame with split value columns 
newphone = data["Contact No."].str.split("/", n = 1, expand = True)  
# making separate column from new data frame 
data["Phone - Mobile"]= newphone[0] 
data["Phone 2- Mobile"]= newphone[1] 
# Dropping old Contact No. column 
data.drop(columns =["Contact No."], inplace = True) 

# new data frame with split value columns 
newEmail = data["Email ID"].str.split(",", n = 1, expand = True)  
# making separate column from new data frame 
data["E-mail 1"]= newEmail[0] 
data["E-mail 2"]= newEmail[1] 
# Dropping old Email ID columns 
data.drop(columns =["Email ID"], inplace = True) 
# Data frame to excel  
df.to_excel('Members.xlsx', index = False, header=True)

# %%
#df.to_excel('dataframe.xlsx', index = False, header=True)


#data = pd.read_excel (r'/Users/akansha/Desktop/video/dataframe.xlsx')

# %%
from bs4 import BeautifulSoup as soup
from urllib.request import urlopen as uReq
uClient = uReq(url)
page_html = uClient.read()
uClient.close()
page_soup = soup(page_html,"html.parser")
containers = page_soup.findAll("div", {"class":"col-md-12"})
print(len(containers))
print(soup.prettify(containers[0]))
# Out:
# <div class="col-md-12">
#  <table class="table">
#   <tr>
#    <th>
#     S.No.
#    </th>
#    <th>
#     Name of Member
#    </th>
#    <th>
#     Event Company
#    </th>
#    <th>
#     Contact No.
#    </th>
#    <th>
#     Email ID
#    </th>
#   </tr>
#   <tr>
#    <td>
#     1
#    </td>
#    <td>
#     Aayush Gupta
#    </td>
#    <td>
#     Anehi Wedding Plaaner Pvt Ltd
#    </td>
#    <td>
#     7597120888
#    </td>
#    <td>
#     anehiweddingplanner@gmail.com
#    </td>
#   </tr>
#   <tr>
#    <td>
#     2
#    </td>
#    <td>
#     Aditya Viay
#    </td>
#    <td>
#     Occasion Events
#    </td>
#    <td>
#     9680361401
#    </td>
#    <td>
#     adityavj31@gmail.com
#    </td>
#   </tr>
#   <tr>
#    <td>
#     3
#    </td>
#    <td>
#     Ajay Agarwal
#    </td>
#    <td>
#     Arch Promotions &amp; Services
#    </td>
#    <td>
#     9829012210
#    </td>
#    <td>
#     ajayagarwal1966@gmail.com
#    </td>
#   </tr>
#   <tr>
#    <td>
#     4
#    </td>
#    <td>
#     Ajay Chouhan
#    </td>
#    <td>
#     Challengers Event
#    </td>
#    <td>
#     9351434630
#    </td>
#    <td>
#     challengersevents@gmail.com
#    </td>
#   </tr>
#   <tr>
#    <td>
#     5
#    </td>
#    <td>
#     Amit Dogra
#    </td>
#    <td>
#     Royal India Wedding
#    </td>
#    <td>
#     9929106781
#    </td>
#    <td>
#     amit@royalindiawedding.com
#    </td>
#   </tr>
#   <tr>
#    <td>
#     6
#    </td>
#    <td>
#     Amit Khunteta
#    </td>
#    <td>
#     Dream Wedding Makers
#    </td>
#    <td>
#     9928314737
#    </td>
#    <td>
#     jaipurtown@gmail.com
#    </td>
#   </tr>
#   <tr>
#    <td>
#     7
#    </td>
#    <td>
#     Ankit Singhvi
#    </td>
#    <td>
#     The Elite Express
#    </td>
#    <td>
#     9468591330
#    </td>
#    <td>
#     eliteindiaevents@gmail.com
#    </td>
#   </tr>
#   <tr>
#    <td>
#     8
#    </td>
#    <td>
#     Anshul Dadhich
#    </td>
#    <td>
#     BrandCraft Events &amp; Promotions
#    </td>
#    <td>
#     9982867075
#    </td>
#    <td>
#     brandcraftevents@gmail.com
#    </td>
#   </tr>
#   <tr>
#    <td>
#     9
#    </td>
#    <td>
#     Apurva Bhargava
#    </td>
#    <td>
#     360 MediaSolutions
#    </td>
#    <td>
#     8233044000
#    </td>
#    <td>
#     apurva@360ms.in
#    </td>
#   </tr>
#   <tr>
#    <td>
#     10
#    </td>
#    <td>
#     Arshad Hussain
#    </td>
#    <td>
#     Event Guru
#    </td>
#    <td>
#     9828070007
#    </td>
#    <td>
#     maileventguru@gmail.com
#    </td>
#   </tr>
#   <tr>
#    <td>
#     11
#    </td>
#    <td>
#     Ashish Sharma
#    </td>
#    <td>
#     Dream Day Wedding
#    </td>
#    <td>
#     9269272025
#    </td>
#    <td>
#    </td>
#   </tr>
#   <tr>
#    <td>
#     12
#    </td>
#    <td>
#     Ashutosh bohra
#    </td>
#    <td>
#     Almas
#    </td>
#    <td>
#     9828251872
#    </td>
#    <td>
#     almasenter@gmail.com
#    </td>
#   </tr>
#   <tr>
#    <td>
#     13
#    </td>
#    <td>
#     Babita Jain
#    </td>
#    <td>
#     Xtravagant
#    </td>
#    <td>
#     9351373147
#    </td>
#    <td>
#     babitaj.12@gmail.com
#    </td>
#   </tr>
#   <tr>
#    <td>
#     14
#    </td>
#    <td>
#     Bharvi Maheshwari
#    </td>
#    <td>
#     Innovative Events
#    </td>
#    <td>
#     9887849950
#    </td>
#    <td>
#     innovativeevents4u@gmail.com
#    </td>
#   </tr>
#   <tr>
#    <td>
#     15
#    </td>
#    <td>
#     Bhuvnesh Agrawal
#    </td>
#    <td>
#     swastik vinayak entertainment &amp; productions LLP
#    </td>
#    <td>
#     9828160627
#    </td>
#    <td>
#     swastikvinayakevents@gmail.com
#    </td>
#   </tr>
#   <tr>
#    <td>
#     16
#    </td>
#    <td>
#     Bhuvnesh Sharma
#    </td>
#    <td>
#     D' weddings
#    </td>
#    <td>
#     7665777250
#    </td>
#    <td>
#     bhuvnisharma@gmail.com
#    </td>
#   </tr>
#   <tr>
#    <td>
#     17
#    </td>
#    <td>
#     Chetan Chabbaria
#    </td>
#    <td>
#     Event Square
#    </td>
#    <td>
#     9829112550
#    </td>
#    <td>
#     eventsquare3@gmail.com
#    </td>
#   </tr>
#   <tr>
#    <td>
#     18
#    </td>
#    <td>
#     Devraj Sharma
#    </td>
#    <td>
#     Ground Zero Events Pvt. Ltd.
#    </td>
#    <td>
#     9829190758
#    </td>
#    <td>
#     groundzeroevent@gmail.com
#    </td>
#   </tr>
#   <tr>
#    <td>
#     19
#    </td>
#    <td>
#     Gaurav Vashisht
#    </td>
#    <td>
#     Royal Occasionz
#    </td>
#    <td>
#     9829310960
#    </td>
#    <td>
#     royaloccasionz@gmail.com
#    </td>
#   </tr>
#   <tr>
#    <td>
#     20
#    </td>
#    <td>
#     Gaurav Verma
#    </td>
#    <td>
#     Mr. Verma Events and Entertainment
#    </td>
#    <td>
#     8384978567
#    </td>
#    <td>
#     mrvermaeventsandentertainment@gmail.com
#    </td>
#   </tr>
#   <tr>
#    <td>
#     21
#    </td>
#    <td>
#     Harpreet Singh
#    </td>
#    <td>
#     Rising Events &amp; Promotions Pvt Ltd.
#    </td>
#    <td>
#     9887388800
#    </td>
#    <td>
#     harpreet@risingevents.org
#    </td>
#   </tr>
#   <tr>
#    <td>
#     22
#    </td>
#    <td>
#     Harsh Samaria
#    </td>
#    <td>
#     Samrock India Event &amp; Entertainment
#    </td>
#    <td>
#     9649920390
#    </td>
#    <td>
#     info@samrockindia.com, samrockindiaevent@gmail.com
#    </td>
#   </tr>
#   <tr>
#    <td>
#     23
#    </td>
#    <td>
#     Hitendra Sharma
#    </td>
#    <td>
#     Aaradhya events &amp; marketing
#    </td>
#    <td>
#     9829075422
#    </td>
#    <td>
#     hitendra_events@gmail.com
#    </td>
#   </tr>
#   <tr>
#    <td>
#     24
#    </td>
#    <td>
#     Kartik Tahiliani
#    </td>
#    <td>
#     Moments of Life
#    </td>
#    <td>
#     8955570109
#    </td>
#    <td>
#     momentsoflifeweddingplanners@gmail.com
#    </td>
#   </tr>
#   <tr>
#    <td>
#     25
#    </td>
#    <td>
#     Kuldeep Singh
#    </td>
#    <td>
#     Red M Exhibitions and Events (P) Ltd.
#    </td>
#    <td>
#     9929544466
#    </td>
#    <td>
#     redmevents@gmail.com
#    </td>
#   </tr>
#   <tr>
#    <td>
#     26
#    </td>
#    <td>
#     Lokendra Pratap Singh
#    </td>
#    <td>
#     Riddhi Entertainment
#    </td>
#    <td>
#     9602282833
#    </td>
#    <td>
#     lokendra8230@gmail.com
#    </td>
#   </tr>
#   <tr>
#    <td>
#     27
#    </td>
#    <td>
#     Mahavir Pratap Sharma
#    </td>
#    <td>
#     Swishin Events LLP
#    </td>
#    <td>
#     9828060003
#    </td>
#    <td>
#     info@swishin.in
#    </td>
#   </tr>
#   <tr>
#    <td>
#     28
#    </td>
#    <td>
#     Mandeep Agarwal
#    </td>
#    <td>
#     Konark Events
#    </td>
#    <td>
#     9929533253
#    </td>
#    <td>
#     konarkevents@gmail.com
#    </td>
#   </tr>
#   <tr>
#    <td>
#     29
#    </td>
#    <td>
#     Manila Gupta
#    </td>
#    <td>
#     Choicest Media Pvt Ltd
#    </td>
#    <td>
#     9829067675
#    </td>
#    <td>
#     guptalm@choicestmedia.com
#    </td>
#   </tr>
#   <tr>
#    <td>
#     30
#    </td>
#    <td>
#     Manish Agarwal
#    </td>
#    <td>
#     Angel Events
#    </td>
#    <td>
#     9024322333
#    </td>
#    <td>
#     mail@angelevents.in, events.angel@yahoo.in
#    </td>
#   </tr>
#   <tr>
#    <td>
#     31
#    </td>
#    <td>
#     Mohit Behal
#    </td>
#    <td>
#     Nexus Entertainerz
#    </td>
#    <td>
#     9887019099
#    </td>
#    <td>
#     nexusentertainerz@gmail.com
#    </td>
#   </tr>
#   <tr>
#    <td>
#     32
#    </td>
#    <td>
#     Mohit Maheshwari
#    </td>
#    <td>
#     Utsav Décor
#    </td>
#    <td>
#     9829088612
#    </td>
#    <td>
#     Info@utsavweddings.com
#    </td>
#   </tr>
#   <tr>
#    <td>
#     33
#    </td>
#    <td>
#     Naman Bhatra
#    </td>
#    <td>
#     Shubhprasang
#    </td>
#    <td>
#     9829060963
#    </td>
#    <td>
#     shubhprasang@gmail.comm
#    </td>
#   </tr>
#   <tr>
#    <td>
#     34
#    </td>
#    <td>
#     Namit Mathur
#    </td>
#    <td>
#     Market Catcher Promotion &amp; Events Pvt. Ltd.
#    </td>
#    <td>
#     9351413344
#    </td>
#    <td>
#     namit.marketcatcher@gmail.com
#    </td>
#   </tr>
#   <tr>
#    <td>
#     35
#    </td>
#    <td>
#     Naveen Sharma
#    </td>
#    <td>
#     Milestone Entertainment
#    </td>
#    <td>
#     8829010501
#    </td>
#    <td>
#     info@milestoneeventz.in
#    </td>
#   </tr>
#   <tr>
#    <td>
#     36
#    </td>
#    <td>
#     Navneet Khandelwal
#    </td>
#    <td>
#     Vision Enterprises
#    </td>
#    <td>
#     9782532320
#    </td>
#    <td>
#     visionplusnkk@gmail.com
#    </td>
#   </tr>
#   <tr>
#    <td>
#     37
#    </td>
#    <td>
#     Nimisha Mishra
#    </td>
#    <td>
#     Mahila Sangeet.com
#    </td>
#    <td>
#     9024540295
#    </td>
#    <td>
#     nimishamishra2109@gmail.com
#    </td>
#   </tr>
#   <tr>
#    <td>
#     38
#    </td>
#    <td>
#     Nisha Jalori
#    </td>
#    <td>
#     Nisha Jalori Events
#    </td>
#    <td>
#     9314002236
#    </td>
#    <td>
#     nisha@jalori.co.in
#    </td>
#   </tr>
#   <tr>
#    <td>
#     39
#    </td>
#    <td>
#     Nishant Bhardwaj
#    </td>
#    <td>
#     Ovations Event &amp; Wedding Planners
#    </td>
#    <td>
#     9950155600
#    </td>
#    <td>
#     shining.nishant@gmail.com
#    </td>
#   </tr>
#   <tr>
#    <td>
#     40
#    </td>
#    <td>
#     Nishi Dhingra
#    </td>
#    <td>
#     Party Popperz
#    </td>
#    <td>
#     9983608880
#    </td>
#    <td>
#     partypopperzjpr@gmail.com
#    </td>
#   </tr>
#   <tr>
#    <td>
#     41
#    </td>
#    <td>
#     Nitin Dubey
#    </td>
#    <td>
#     Vivaan Creations
#    </td>
#    <td>
#     9829166214
#    </td>
#    <td>
#     nitindubey2602@gmail.com
#    </td>
#   </tr>
#   <tr>
#    <td>
#     42
#    </td>
#    <td>
#     Padmesh Kumar Jain
#    </td>
#    <td>
#     EVENTUALLY
#    </td>
#    <td>
#     8952033333
#    </td>
#    <td>
#     padmeshjain21@gmail.com
#    </td>
#   </tr>
#   <tr>
#    <td>
#     43
#    </td>
#    <td>
#     Prasanjeet Maloo
#    </td>
#    <td>
#     VEENA MUSIC &amp; EVENTS WEDDING CONSULTANT
#    </td>
#    <td>
#     9829061988
#    </td>
#    <td>
#     prasanjitmaloo3@gmail.com
#    </td>
#   </tr>
#   <tr>
#    <td>
#     44
#    </td>
#    <td>
#     Prateek Joshi
#    </td>
#    <td>
#     Impression the event maker
#    </td>
#    <td>
#     8003377655
#    </td>
#    <td>
#     impressioneventmaker@gmail.com
#    </td>
#   </tr>
#   <tr>
#    <td>
#     45
#    </td>
#    <td>
#     Priyanka Dubey
#    </td>
#    <td>
#     Priyanka's Event Organiser
#    </td>
#    <td>
#     7737722486
#    </td>
#    <td>
#     priyankasevent@gmail.com
#    </td>
#   </tr>
#   <tr>
#    <td>
#     46
#    </td>
#    <td>
#     Rahul Dadhich
#    </td>
#    <td>
#     Shiv Shakti Entertainment
#    </td>
#    <td>
#     9314531363
#    </td>
#    <td>
#     rahul@shivshaktientertainment.com
#    </td>
#   </tr>
#   <tr>
#    <td>
#     47
#    </td>
#    <td>
#     Rajiv Agarwal
#    </td>
#    <td>
#     Jems Evento
#    </td>
#    <td>
#     9660212958
#    </td>
#    <td>
#     rajivevent@gmail.com
#    </td>
#   </tr>
#   <tr>
#    <td>
#     48
#    </td>
#    <td>
#     Rajeev Naamjoshi
#    </td>
#    <td>
#     Srishthi Sanchar Events
#    </td>
#    <td>
#     9828020543
#    </td>
#    <td>
#     rajeev@srishthisanchar.com
#    </td>
#   </tr>
#   <tr>
#    <td>
#     49
#    </td>
#    <td>
#     Reema Agarwal
#    </td>
#    <td>
#     Purple Grapes events
#    </td>
#    <td>
#     7014329209
#    </td>
#    <td>
#     purple.grapes19@gmail.com
#    </td>
#   </tr>
#   <tr>
#    <td>
#     50
#    </td>
#    <td>
#     Richa sharma
#    </td>
#    <td>
#     Hospitality mantra
#    </td>
#    <td>
#     9116013948
#    </td>
#    <td>
#     sales@hospitalitymantra.com
#    </td>
#   </tr>
#   <tr>
#    <td>
#     51
#    </td>
#    <td>
#     Rohit Agarwal
#    </td>
#    <td>
#     Events Mantra .com
#    </td>
#    <td>
#     9828486055
#    </td>
#    <td>
#     rohit@eventsmantra.com
#    </td>
#   </tr>
#   <tr>
#    <td>
#     52
#    </td>
#    <td>
#     Ronak Baid
#    </td>
#    <td>
#     Occasions Era
#    </td>
#    <td>
#     9509544940/ 8890323459
#    </td>
#    <td>
#     occasionsera@gmail.com
#    </td>
#   </tr>
#   <tr>
#    <td>
#     53
#    </td>
#    <td>
#     Sahil Nagpal
#    </td>
#    <td>
#     Event Shapers LLP
#    </td>
#    <td>
#     9929599302
#    </td>
#    <td>
#     eventshapersllp@gmail.com
#    </td>
#   </tr>
#   <tr>
#    <td>
#     54
#    </td>
#    <td>
#     Sanjay Agarwal
#    </td>
#    <td>
#     Shubh Shagun
#    </td>
#    <td>
#     9829845414/8290050001
#    </td>
#    <td>
#     sanjay4events@gmail.com
#    </td>
#   </tr>
#   <tr>
#    <td>
#     55
#    </td>
#    <td>
#     Sankalp Vidhani
#    </td>
#    <td>
#     R-Square Events
#    </td>
#    <td>
#     9887766116 / 7976647076
#    </td>
#    <td>
#     sankalpvidhani@gmail.com
#    </td>
#   </tr>
#   <tr>
#    <td>
#     56
#    </td>
#    <td>
#     Sharmendra Singh
#    </td>
#    <td>
#     Wildcard Media Pvt Ltd.
#    </td>
#    <td>
#     9828294005
#    </td>
#    <td>
#     wildcardmedia@gmail.com
#    </td>
#   </tr>
#   <tr>
#    <td>
#     57
#    </td>
#    <td>
#     Shashank Sharma
#    </td>
#    <td>
#     The Royal Host
#    </td>
#    <td>
#     9610433953
#    </td>
#    <td>
#     theroyalhost@gmail.com
#    </td>
#   </tr>
#   <tr>
#    <td>
#     58
#    </td>
#    <td>
#     Shobhana Tuwani
#    </td>
#    <td>
#     Innovations
#    </td>
#    <td>
#     9214608311
#    </td>
#    <td>
#     innovations.jpr@gmail.com
#    </td>
#   </tr>
#   <tr>
#    <td>
#     59
#    </td>
#    <td>
#     Simran Bhatiya
#    </td>
#    <td>
#     Noon Moon Events
#    </td>
#    <td>
#     7568223594
#    </td>
#    <td>
#     simran@noonmooneventscom
#    </td>
#   </tr>
#   <tr>
#    <td>
#     60
#    </td>
#    <td>
#     Spectrum The Event
#    </td>
#    <td>
#     Akash Bang
#    </td>
#    <td>
#     8852089995/ 9414089995
#    </td>
#    <td>
#     info@spectrum-events.in
#    </td>
#   </tr>
#   <tr>
#    <td>
#     61
#    </td>
#    <td>
#     Sunil Shekhawat(Shivraj)
#    </td>
#    <td>
#     Rajpuitana Rock on
#    </td>
#    <td>
#     9983500007
#    </td>
#    <td>
#     sunil.shivraj@gmail.com
#    </td>
#   </tr>
#   <tr>
#    <td>
#     62
#    </td>
#    <td>
#     Sunil Vijayvergiya
#    </td>
#    <td>
#     Preetesh Event &amp; Entertainment
#    </td>
#    <td>
#     9784010944
#    </td>
#    <td>
#     preetesh.events@gmail.com
#    </td>
#   </tr>
#   <tr>
#    <td>
#     63
#    </td>
#    <td>
#     Suresh Jajoo
#    </td>
#    <td>
#     Bask Entertainment Co.
#    </td>
#    <td>
#     9982221213
#    </td>
#    <td>
#     baskentertainment@gmail.com
#    </td>
#   </tr>
#   <tr>
#    <td>
#     64
#    </td>
#    <td>
#     Suresh Madhavan
#    </td>
#    <td>
#     Ample Creations
#    </td>
#    <td>
#     7976175016/ 9829567009
#    </td>
#    <td>
#     ac.jpr21@gmail.com
#    </td>
#   </tr>
#   <tr>
#    <td>
#     65
#    </td>
#    <td>
#     Tarun Malaviya
#    </td>
#    <td>
#     Magnum Events &amp; experiences
#    </td>
#    <td>
#     9829052700
#    </td>
#    <td>
#     tarun.magnumesp@gmail.com
#    </td>
#   </tr>
#   <tr>
#    <td>
#     66
#    </td>
#    <td>
#     Teekendra Singh
#    </td>
#    <td>
#     Tuma Events
#    </td>
#    <td>
#     9828557711
#    </td>
#    <td>
#     ceo@tumahotelsindia.com
#    </td>
#   </tr>
#   <tr>
#    <td>
#     67
#    </td>
#    <td>
#     Vikas Jain
#    </td>
#    <td>
#     Odyssey Events
#    </td>
#    <td>
#     8441812345
#    </td>
#    <td>
#     info@odysseyevents.in
#    </td>
#   </tr>
#   <tr>
#    <td>
#     68
#    </td>
#    <td>
#     Vikram Singh Shekhawat
#    </td>
#    <td>
#     Vasundhra Event Holidays Pvt.Ltd.
#    </td>
#    <td>
#     8963007001
#    </td>
#    <td>
#     groupvasundhra@gmail.com
#    </td>
#   </tr>
#   <tr>
#    <td>
#     69
#    </td>
#    <td>
#     Vikrant Jain
#    </td>
#    <td>
#     Show Makers India
#    </td>
#    <td>
#     9928022044
#    </td>
#    <td>
#     vikrant@showmakersindia.com
#    </td>
#   </tr>
#   <tr>
#    <td>
#     70
#    </td>
#    <td>
#     Vinit Jain
#    </td>
#    <td>
#     Starworks Entertainment
#    </td>
#    <td>
#     9829225536
#    </td>
#    <td>
#     starworks100@gmail.com
#    </td>
#   </tr>
#   <tr>
#    <td>
#     71
#    </td>
#    <td>
#     Yash Maheshwari
#    </td>
#    <td>
#     J Y Events
#    </td>
#    <td>
#     8384902370/ 6375883172
#    </td>
#    <td>
#     jyeventsjaipur@gmail.com
#    </td>
#   </tr>
#  </table>
# </div>

# %%
name=container.findAll("table", {"class":"table"})
a=name[0].text

# %%
# Out:
#   File "<ipython-input-82-fc848593ad2a>", line 1
#     pip3 install requests beautifulsoup4
#                ^
# SyntaxError: invalid syntax
